# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.linspace(0,3,100)
y=np.exp(-x)

# %%
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.yscale('log')

# %%
plt.plot(x,y)
plt.xscale('log')
plt.yscale('log')

# %%
plt.plot(x,y)
plt.xscale('log')
